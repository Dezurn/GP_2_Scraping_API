# %%
import pandas as pd

# %%
df_sj, df_rr = pd.read_csv('../datasets/superjob_vacancies.csv'), pd.read_csv('../datasets/rabota_ru_formated.csv')
df_sj
# Out:
#             id                                  Название вакансии  \
# 0     31948884                            Системный администратор
# 1     50742146                             Администратор магазина
# 2     46781727                            Системный администратор
# 3     51673017                         Инженер по АСУ ТП (ТЭЦ-21)
# 4     51729020  Инженер 1 категории (отдел по работе с обращен...
# ...        ...                                                ...
# 2674  46603831        Рабочий по комплексному обслуживанию здания
# 2675  47869139               Мастер по текущему ремонту (Плотник)
# 2676  51707520                      Электромонтер контактной сети
# 2677  51760926                 Стажер системный инженер (BigData)
# 2678  51863366         Автокурьер на личном авто (Оплата патента)
#
#       Минимальная зарплата  Максимальная зарплата Валюта  \
# 0                    65000                      0    rub
# ...

# %%
df_rr
# Out:
#        Unnamed: 0                                  Название вакансии  \
# 0               0                               Парикмахер-универсал
# 1               1                          Ведущий научный сотрудник
# 2               2             Водитель-курьер на доставку сантехники
# 3               3                     Водитель-курьер на личном авто
# 4               4  Медицинский писатель (Координационный центр фе...
# ...           ...                                                ...
# 12641       12676                       Водитель категории С (вахта)
# 12642       12677                                       Разнорабочий
# 12643       12678                                           Водитель
# 12644       12679                                           Рекрутер
# 12645       12680                                           Охранник
#
#                   Зарплата                                   Требуемые навыки  \
# ...
